# %%
import numpy as np
import pandas as pd
import warnings

# %%
# set options
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
# read clean Open 2019 dataset
df_19 = pd.read_csv('./data/2019_opens_clean.csv')
df_19 = df_19.loc[:, ~df_19.columns.str.contains('^Unnamed')]
df_19 = df_19.dropna()

# %%
df_19.head()
# Out:
#     competitorid firstname   lastname gender countryoforigincode  affiliateid  \
# 0             86    Justin      Bergh      M                  US        19273
# 3             93      Leif  Edmundson      M                  US        19273
# 14          1646     Chris   Hamilton      M                  US        15578
# 17          1651      John       Ryan      M                  US        20024
# 20          1662      Joel   Stephens      M                  US         4830
#
#                  affiliatename   age  height  weight  overallrank  \
# 0                  CrossFit HQ  37.0    1.96  102.06        53022
# 3                  CrossFit HQ  37.0    1.83   92.99        38765
# 14  CrossFit Northern Kentucky  39.0    1.75   83.91        66431
# 17          Fairwinds CrossFit  42.0    1.68   74.84        25323
# 20        South Tampa CrossFit  40.0    1.78   84.82        25255
#
#     overallscore  is_scaled     division  rank_1  rank_2  rank_3  rank_4  \
# 0         304948          0  Men (35-39)   15232   58534   59298   85576
# 3         237798          0  Men (35-39)   50223   39468   78855   40425
# 14        362753          0  Men (35-39)  110746   57905   64386   79620
# 17        168626          0  Men (40-44)   37269   86240   12840   16303
# 20        168171          0  Men (40-44)   43323   37453   38465   32012
#
#     rank_5  time_1  time_2  time_3  time_4  time_5  scaled_1  scaled_2  \
# 0    86308   900.0   480.0   600.0   720.0  1200.0         0         0
# 3    28827   900.0   480.0   600.0   720.0  1200.0         0         0
# 14   50096   900.0   480.0   600.0   720.0  1200.0         0         0
# 17   15974   900.0   480.0   600.0   720.0  1092.0         0         0
# 20   16918   900.0   480.0   600.0   720.0  1105.0         0         0
#
#     scaled_3  scaled_4  scaled_5   score_1   score_2   score_3   score_4  \
# 0          0         0         0  13040000  11670764  10980237  10720255
# 3          0         0         0  12670000  11720803  10920171  10970472
# 14         0         0         0  12270000  11670778  10970071  10740401
# 17         0         0         0  12790000  11241104  11250236  11150505
# 20         0         0         0  12730000  11720857  11070170  11070470
#
#      score_5  bs_backsquat  bs_cleanandjerk  bs_snatch  bs_deadlift  \
# 0   11350000         151.0            120.0       95.0        188.0
# 3   12010000         138.0            106.0       83.0        161.0
# 14  11730000         142.0            102.0       79.0        174.0
# 17  12100108         156.0            108.0       81.0        201.0
# 20  12100095         147.0            111.0       77.0        215.0
#
#     bs_fightgonebad  bs_maxpull_ups  bs_fran  bs_grace  bs_helen  bs_filthy50  \
# 0             393.0            32.0    226.0     174.0     496.0       1287.0
# 3             403.0            45.0    220.0     154.0     493.0       1500.0
# 14            290.0            30.0    202.0     200.0     599.0       1626.0
# 17            365.0            45.0    191.0     183.0     403.0       1339.0
# 20            340.0            40.0    187.0     146.0     489.0       1287.0
#
#     bs_sprint400m  bs_run5k  w1_reps_total  w1_reps_wbs  w1_cals_row  \
# 0            64.0    1325.0          304.0        152.0        152.0
# 3            62.0    1239.0          267.0        134.0        133.0
# 14           75.0    1665.0          227.0        114.0        113.0
# 17           61.0    1132.0          279.0        146.0        133.0
# 20           79.0    1356.0          273.0        140.0        133.0
#
#     w1_rounds_completed  w2_reps_total  w2_reps_t2b  w2_reps_du  w2_reps_sqcl  \
# 0                  8.00          167.0         50.0       100.0          17.0
# 3                  7.03          172.0         50.0       100.0          22.0
# 14                 5.97          167.0         50.0       100.0          17.0
# 17                 7.34          124.0         50.0        59.0          15.0
# 20                 7.18          172.0         50.0       100.0          22.0
#
#     w2_rounds_completed  w2_tiebreak  w3_reps_total  w3_5ft_reps_ohl  \
# 0                  1.88        436.0           98.0             40.0
# 3                  1.93        397.0           92.0             40.0
# 14                 1.88        422.0           97.0             40.0
# 17                 1.39         96.0          125.0             40.0
# 20                 1.93        343.0          107.0             40.0
#
#     w3_reps_dbbsu  w3_reps_hspu  w3_hspu_status  w3_5ft_reps_hsw  \
# 0            50.0           8.0             1.0              0.0
# 3            50.0           2.0             1.0              0.0
# 14           50.0           7.0             1.0              0.0
# 17           50.0          35.0             1.0              0.0
# 20           50.0          17.0             1.0              0.0
#
#     w3_rounds_completed  w3_tiebreak  w4_reps_total  w4_reps_sn  w4_reps_bp  \
# 0                  2.16        363.0           72.0        30.0        36.0
# 3                  2.04        429.0           97.0        30.0        48.0
# 14                 2.14        529.0           74.0        30.0        36.0
# 17                 2.70        364.0          115.0        30.0        60.0
# 20                 2.34        430.0          107.0        30.0        57.0
#
#     w4_reps_bmu  w4_bmu_status  w4_rounds_completed  w4_tiebreak  \
# 0           6.0            1.0                 1.09        465.0
# 3          19.0            1.0                 1.47        248.0
# 14          8.0            1.0                 1.12        319.0
# 17         25.0            1.0                 1.74        215.0
# 20         20.0            1.0                 1.62        250.0
#
#     w5_reps_total  w5_reps_thr  w5_reps_c2bpu  w5_rounds_completed        BMI
# 0           135.0         75.0           60.0                 2.36  26.567055
# 3           201.0        105.0           96.0                 4.50  27.767327
# 14          173.0         92.0           81.0                 3.37  27.399184
# 17          210.0        105.0          105.0                 5.00  26.516440
# 20          210.0        105.0          105.0                 5.00  26.770610

# %%
problem = {
    'num_vars': 3,
    'names': ['age', 'height', 'weight'],
    'bounds': [[-3.14159265359, 3.14159265359],
               [-3.14159265359, 3.14159265359],
               [-3.14159265359, 3.14159265359]]
}
